# %%
l=[23,45,67,89,12]

# %%
print(l)
# Out:
# [23, 45, 67, 89, 12]

# %%
# list hetero and duplicate are allowed

# %%
l1=[23,45,67.90,89,12,"python","java",23,45]

# %%
print(l1)
# Out:
# [23, 45, 67.9, 89, 12, 'python', 'java', 23, 45]

# %%
# list are ordered

# %%
l1
# Out:
# [23, 45, 67.9, 89, 12, 'python', 'java', 23, 45]

# %%
l1[2:5]
# Out:
# [67.9, 89, 12]

# %%
l1[-3]
# Out:
# 'java'

# %%
# list are mutable

# %%
l1[1]=100

# %% [markdown]
# #

# %%
l1
# Out:
# [23, 100, 67.9, 89, 12, 'python', 'java', 23, 45]

# %%
l1[6]=True

# %%
l1
# Out:
# [23, 100, 67.9, 89, 12, 'python', True, 23, 45]

# %%
# list slicing

# %%
l=[21,23,45,67,89,11]

# %%
l
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[1:4]
# Out:
# [23, 45, 67]

# %%
l[1:-2]
# Out:
# [23, 45, 67]

# %%
# 21,45,89

# %%
l[0:6:2]
# Out:
# [21, 45, 89]

# %%
# reverse list

# %%
l.reverse()

# %%
l
# Out:
# [21, 23, 300, 200, 100, 11]

# %%
l[6:0]
# Out:
# []

# %%
l.reverse()

# %%
l[1:4]=[100,200,300]

# %%
l
# Out:
# [11, 100, 200, 300, 100, 21]

# %%
del l1[-2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 del l1[-2]
#
# NameError: name 'l1' is not defined

# %%
l1
# Out:
# [23, 100, 67.9, 89, 12, 'python', True, 45]

# %%
del l1

# %%
# membership operator

# %%
l1=[21,100,200,300,89,11]

# %%
l1
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
89 in l1
# Out:
# True

# %%
1038 in l1
# Out:
# False

# %%
# arithmetic operator

# %%
l1*2
# Out:
# [21, 100, 200, 300, 89, 11, 21, 100, 200, 300, 89, 11]

# %%
l+[60,70,80]
# Out:
# [11, 100, 200, 300, 100, 21, 60, 70, 80]

# %%
# take two list and add them

# %%
list1=[1,2,3,]

# %%
list1
# Out:
# [1, 2, 3]

# %%
list2=[4,5,6]

# %%
list1+list2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# iterate over list and print square of each element

# %%
for i in list1:
    print(i*i,end=' ')
# Out:
# 149

# %%
for i in l1:
    if i%2==1:
        print(i)
# Out:
# 21
# 89
# 11

# %%
# list comprehension - > [expression for_lopp if_condition]

# %%
new1=[i**2 for i in l1]

# %%
new1
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
new1=[i for i in l1 if(i % 2==1) ]

# %%
new1
# Out:
# [21, 89, 11]

# %%
names=["Aryan","atharv","samruddhi","swaraj","Sukanya","shivraj"]

# %%
names
# Out:
# ['Aryan', 'atharv', 'samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
# create a new list with names which starts with 's' or 'S'

# %%
name1=[ i for i in names if i.lower().startswith('s')]

# %%
name1
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
for i in names:
    if i.lower().startswith('s'):
        print(i)
# Out:
# samruddhi
# swaraj
# Sukanya
# shivraj

# %%
for i in names:
    if i[0]=='s' or i[0]=='S':
        print(i)
# Out:
# samruddhi
# swaraj
# Sukanya
# shivraj

# %%
# function

# %%
min(l1)
# Out:
# 11

# %%
sorted(l1)
# Out:
# [11, 21, 89, 100, 200, 300]

# %%
sorted(l1,reverse=True)
# Out:
# [300, 200, 100, 89, 21, 11]

# %%
# list methods

# %%
#append

# %%
l1
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l1.append(1000)

# %%
l1
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l4=[1,2,3]
l5=[1,2,3]

# %%
l4.append([100,200])
l5.extend([100,200])

# %%
l4
# Out:
# [1, 2, 3, [100, 200], [100, 200]]

# %%
l5
# Out:
# [1, 2, 3, 100, 200, 100, 200]

# %%
l4[3]
# Out:
# [100, 200]

# %%
l4[3][1]
# Out:
# 200

# %%
l4[3][1]=37251289

# %%
l4
# Out:
# [1, 2, 3, [100, 37251289], [100, 200]]

# %%
#insert

# %%
l1
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l1.insert(1,78)

# %%
l1
# Out:
# [21, 78, 100, 200, 300, 89, 11, 1000]

# %%
l1.remove(78)
l1
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l1.pop()
# Out:
# 1000

# %%
l1.pop(3)
# Out:
# 300

# %%
l1
# Out:
# [21, 100, 200, 89, 11]

# %%
l1.index(89)
# Out:
# 3

# %%
l1.sort(reverse=True)

# %%
l1
# Out:
# [200, 100, 89, 21, 11]
