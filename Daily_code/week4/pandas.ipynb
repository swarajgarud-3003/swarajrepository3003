# %%
# pandas

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\swara\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\swara\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\swara\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\swara\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\swara\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\swara\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#1d data structures in pandas

# %%
#Pandas Series

# %%
#Creating Panda Series

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s=pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s=pd.Series(["swaraj",18,100],index=['name','age','marks'])

# %%
s
# Out:
# name     swaraj
# age          18
# marks       100
# dtype: object

# %%
#From dictionary

# %%
data={"name":"Rahul","age":35,"marks":90}

# %%
s=pd.Series(data)

# %%
s
# Out:
# name     Rahul
# age         35
# marks       90
# dtype: object

# %%
data={"subject":"python","age":35,"year":90,"marks":89}

# %%
s=pd.Series(data)

# %%
s
# Out:
# subject    python
# age            35
# year           90
# marks          89
# dtype: object

# %%
# from a single value

# %%
s=pd.Series(5,index=[0,1,2,3,45,5,4,])

# %%
s
# Out:
# 0     5
# 1     5
# 2     5
# 3     5
# 45    5
# 5     5
# 4     5
# dtype: int64

# %%
# Attributes

# %%
s=pd.Series([10,20,30],index=["a","b","c"])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
# data manipulation

# %%
s=pd.Series([1,2,3])

# %%
s*3
# Out:
# 0    3
# 1    6
# 2    9
# dtype: int64

# %%
# Handling Missing Values

# %%
s=pd.Series([1,None,3])

# %%
s
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    1.0
# 2    3.0
# dtype: float64

# %%
s.fillna(75)
# Out:
# 0     1.0
# 1    75.0
# 2     3.0
# dtype: float64

# %%
#indexing

# %%
s=pd.Series([10,20,30],index=["a","b","c"])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
import pandas as pd

# %%
roll=pd.Series([1,2,3,4,5])
name=pd.Series(['sia','ravi','geet','ajeenkya','avinash'])
marks=pd.Series([85,67,59,40,90])

# %%
df=pd.DataFrame({
    'id':roll,
    'name':name,
    'marks':marks
})

# %%
df
# Out:
#    id      name  marks
# 0   1       sia     85
# 1   2      ravi     67
# 2   3      geet     59
# 3   4  ajeenkya     40
# 4   5   avinash     90

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (5, 3)

# %%
df.size
# Out:
# 15

# %%
df.columns
# Out:
# Index(['id', 'name', 'marks'], dtype='object')

# %%
"""
url https://mitu.co.in/dataset will connect to drive folder

download all the datasets starting with student*
put them in the same file folder as ur current working directory
""";

# %%
import pandas as pd

# %%
df=pd.read_csv("student.csv")

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df=pd.read_csv("student1.csv")

# %%
df
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
col=['roll','name','class','marks','age']

# %%
df=pd.read_csv("student1.csv",names=col)

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
# student3.tsv

# %%
df=pd.read_csv("student3.tsv",sep='\t')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21
