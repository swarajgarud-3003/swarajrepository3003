# %%
import numpy as np

# %%
import time

# %%
start=time.time()

# %%
sample_array=np.array([1,2,3,4,5])

# %%
np.sqrt(sample_array)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        , 2.23606798])

# %%
end=time.time()

# %%
start
# Out:
# 1781588046.5855837

# %%
start=time.time()

# %%
sample_array=np.array([100,200,300,400])

# %%
for i in sample_array:
    print(i*i)
# Out:
# 10000
# 40000
# 90000
# 160000

# %%
end=time.time()

# %%
difference=start-end

# %%
print(difference)
# Out:
# -2.2468090057373047

# %%
start1=time.time()

# %%
list=[100,200,300,400]

# %%
for i in list:
    print(i*i)
# Out:
# 10000
# 40000
# 90000
# 160000

# %%
end1=time.time()

# %%
diff=start1-end1

# %%
print(diff)
# Out:
# -3.3173434734344482

# %%
difference/diff
# Out:
# 0.6772916412575095

# %%
sample_array=np.array([1,2,3,4])

# %%
sum=0
for i in sample_array:
    sum=sum+i
print(sum)
# Out:
# 10

# %%
sample_array=np.array([1,2,3,45,6])

# %%
np.max(sample_array)
# Out:
# np.int64(45)
