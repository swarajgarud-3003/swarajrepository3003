# %%
# string functions

# %%
name = "Nitish"

# %%
name.lower()
# Out:
# 'nitish'

# %%
name
# Out:
# 'Nitish'

# %%
name = name.lower()

# %%
name
# Out:
# 'nitish'

# %%
name.upper()
# Out:
# 'NITISH'

# %%
name.title()
# Out:
# 'Nitish'

# %%
name = "Nitish"

# %%
name.swapcase()
# Out:
# 'nITISH'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name3.isalnum()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
name = " Pune "

# %%
print(name)
# Out:
#  Pune

# %%
name.startswith("P")
# Out:
# False

# %%
name.startswith(" P")
# Out:
# True

# %%
name.endswith(" Pune ")
# Out:
# True

# %%
name.endswith("e")
# Out:
# False

# %%
name.endswith("e ")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'Pune '

# %%
name.rstrip()
# Out:
# ' Pune'

# %%
name.strip()
# Out:
# 'Pune'

# %%
name
# Out:
# ' Pune '

# %%
len(name)
# Out:
# 6

# %%
name.replace('u', 'oo')
# Out:
# ' Poone '

# %%
#Operators

# %%
# arithmetic

# %%
a = 5
b = 17

# %%
a + b
# Out:
# 22

# %%
a - b
# Out:
# -12

# %%
b / a
# Out:
# 3.4

# %%
a * b
# Out:
# 85

# %%
a ** b # raise to
# Out:
# 762939453125

# %%
b // a  # floor div
# Out:
# 3

# %%
b // a  # floor div
# Out:
# 3

# %%
b % a
# Out:
# 2

# %%
# assignment operator

# %%
z = 5

# %%
z
# Out:
# 5

# %%
z = z + 3
z
# Out:
# 8

# %%
z += 3
z
# Out:
# 11

# %%
z -= 3

# %%
z
# Out:
# 8

# %%
z *= 3

# %%
z
# Out:
# 24

# %%
# comparison

# %%
a
# Out:
# 5

# %%
b
# Out:
# 17

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# logical operator

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
# identity operator -> is,is not

# %%
a = 5
b = 5

# %%
id(a), id(b)
# Out:
# (140719509513256, 140719509513256)

# %%
a is b
# Out:
# True

# %%
a = [3,4]
b=  [3,4]

# %%
 id(a), id(b)
# Out:
# (2282097185920, 2282095205184)

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)
a
# Out:
# [3, 4, 10, 10, 10, 10]

# %%
z
# Out:
# [3, 4, 10, 10, 10, 10]

# %%
# membership selection operator -> in

# %%
l = [4, 6, 19, 10]

# %%
6 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %%
# bodmas

# %%
5 + 2 - 10
# Out:
# -3

# %%
(4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3
# Out:
# 256

# %%
2 ** 3 / 2
# Out:
# 4.0

# %% [markdown]
# # print Function

# %%
name ="Aryan"

# %%
marks =99.99

# %%
print("my name is",name, "and marks are" ,marks)
# Out:
# my name is Aryan and marks are 99.99

# %%
print(" my name is %s and marks is %i"%(name,marks))
# Out:
#  my name is Aryan and marks is 99

# %%
print(" my name is %s and marks is %f"%(name,marks))
# Out:
#  my name is Aryan and marks is 99.990000

# %%
print(f"My name is{name} and  marks are {marks}")#f is nothing but format!!!!
# Out:
# My name isAryan and  marks are 99.99

# %% [markdown]
# # Dir and Help1

# %%
name
# Out:
# 'Aryan'

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
help(name.isupper)
# Out:
# Help on built-in function isupper:
#
# isupper() method of builtins.str instance
#     Return True if the string is an uppercase string, False otherwise.
#
#     A string is uppercase if all cased characters in the string are uppercase and
#     there is at least one cased character in the string.

# %%
# asciii value

# %%
ord('a') # return asciii numberss
# Out:
# 97

# %%
chr(65) # return characters /alphabets  of the given aciiii number
# Out:
# 'A'

# %% [markdown]
# # Type Casting

# %%
num1 =34

# %%
num2=44.5

# %%
num3='ok'

# %%
num2=float(num1)

# %%
num2
# Out:
# 34.0

# %%
num2=str(num1)

# %%
num2
# Out:
# '34'

# %%
str(num2)
# Out:
# '34'

# %% [markdown]
# # User Input

# %%
a =int(input("Enter user to give value"))
b =int(input("Enter user to give no"))
print ("Addition of Two No:",a+b)
# Out:
# Enter user to give value 77
# Enter user to give no 09
# Addition of Two No: 86

# %%
a =(input("Enter user to give value"))# if we not use specific datatype it will take it as string value and after add operation it will concat the both input
b =(input("Enter user to give no"))
print ("Addition of Two No:",a+b)
# Out:
# Enter user to give value aryan
# Enter user to give no konde
# Addition of Two No: aryankonde

# %%
"""
read the time in second as user input 
and print the time in the format as hour:minutes:seconds


eg:
input->125sec
output -> 00:02:05
"""
# Out:
# '\nread the time in second as user input \nand print the time in the format as hour:minutes:seconds\n\n\neg:\ninput->125sec\noutput -> 00:02:05\n'

# %%
sec =int(input("Enter sec to cal:"))
min=sec//3600
# Out:
# Enter sec to cal: 2
