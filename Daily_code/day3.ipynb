# %%
num = int(input("enter the no"))

if num > 5:
    print('yes')
# Out:
# enter the no 6
# yes

# %%
num = int(input("enter the no"))

if num > 5:
    print('yes')
else:
    print('no')
# Out:
# enter the no 4
# no

# %%
# write a program to check if the number is +ve or -ve

# %%
num = int(input("enter the number"))

if num > 0:
    print('positive')
elif num == 0:
    print('number is zero')
else:
    print('negative')
# Out:
# enter the number 0
# number is zero

# %%
# check if the number is even or odd

# %%
num = int(input("enter the number"))

if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# enter the number -1
# odd

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True + True + False
# Out:
# 2

# %%
a = 1

if a:
    print('exists')
# Out:
# exists

# %%
# check the number is between 50 and 100 0r not (use nested if)

# %%
num = int(input("enter the number"))

if num >= 50:
    if num <= 100:
        print("number is between 50 or 100")
    else:
        print("number is not between 50 or 100")
else:
    print("number is less than  50 ")
# Out:
# enter the number 100
# number is between 50 or 100

# %%
# do the same programe with logical operator

# %%
num =int(input("enter the number"))

if num >= 50 and num <=100:
    print("number is berrtween 50 and 100")
else:
    print("number is not between 50 and 100")
# Out:
# enter the number 50
# number is berrtween 50 and 100

# %%
# read purchase cost and selling cost from the user
# state profit or loss

# %%
purchasecost = 1000

sellingcost =int(input("enter the number"))
if sellingcost > purchasecost:
    print(f"profit of => {sellingcost - purchasecost}")
else:
    print(f"loss of => {sellingcost - purchasecost}")
# Out:
# enter the number 5000
# profit of => 4000

# %%
"""
2020-> leap
2017 -> not leap
2000 -> leap
1800 -> not leap
""";

# %%
# use nested if only ("and or not allowed ")

# %%
year = int(input("Enter year: "))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("Leap Year")
        else:
            print("Not Leap Year")
    else:
        print("Leap Year")
else:
    print("Not Leap Year")
# Out:
# Enter year:  2020
# Leap Year

# %%
"""

take 3 numbers
find which one is largest (use nested if only)
""";

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))

if num1 > num2:
    if num1 > num3:
        print("num1 is greater")
    else:
        print("num3 is greater")
else:
    if num2 > num3:
        print("num2 is greater")
    else:
        print("num3 is greater")
# Out:
# Enter number 1:  5
# Enter number 2:  3
# Enter number 3:  2
# num1 is greater

# %%
print("welcome")
num = int(input("enter the number "))
print("Menu=>n1. Square\n2. Cube\n3. check +ve or -ve")

ch =int(input("select ur choice"))

if ch == 1:
    print(num * num)
elif ch == 2:
    print(num ** 3)
elif ch == 3:
    if num > 0:
        print("positive")
    elif num == 0:
        print("zero")
    else:
        print("negative")
else:
    print("please visit nearest hospital to check ue eyes!!!")
# Out:
# welcome
# enter the number  3
# Menu=>n1. Square
# 2. Cube
# 3. check +ve or -ve
# select ur choice 3
# positive

# %%
"""
take a string from the user
menu -> 1 upper, 2 lowercase, 3 replace a particular part of the string 
for third ption it should which part to replace with what
""";

# %%
print("welcome")
text = input("enter the string")

print("menu =>\n1. upper\n2. lower\n3. replace")
ch = int(input("enter your choice"))

if ch == 1:
    print(text.upper())

elif ch == 2:
    print(text.lower())

elif ch == 3:
    r1 = input("which part u want to replace: ")
    r2 = input("what u want to replace it with: ")

    new = text.replace(r1, r2)

    print("result ->", new)

else:
    print("invalid choice")
# Out:
# welcome
# enter the string swaraj
# menu =>
# 1. upper
# 2. lower
# 3. replace
# enter your choice 1
# SWARAJ
