# %%
"""
create a sample file
""";

# %%
f=open("Sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='Sample.txt' mode='r' encoding='cp1252'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# 'A file is a collection of data stored on a computer or device under a specific name.\n'

# %%
f.readline()
# Out:
# '\n'

# %%
f.readline()
# Out:
# 'Examples of files include:\n'

# %%
f=open("Sample.txt")

# %%
f.readline(10)
# Out:
# 'A file is '

# %%
f.readline(5)
# Out:
# 'a col'

# %%
f.tell()
# Out:
# 15

# %%
f.seek(10)
# Out:
# 10

# %%
# check readlines

# %%
f=open("Sample.txt")

# %%
f.readlines()
# Out:
# ['A file is a collection of data stored on a computer or device under a specific name.\n',
#  '\n',
#  'Examples of files include:\n',
#  '\n',
#  'Documents: report.docx, notes.txt, resume.pdf\n',
#  'Images: photo.jpg, logo.png\n',
#  'Audio: song.mp3\n',
#  'Videos: movie.mp4\n',
#  'Programs: app.exe, script.py\n',
#  '\n',
#  'Each file usually has:\n',
#  '\n',
#  'A name (e.g., vacation_photo)\n',
#  'An extension/type (e.g., .jpg) that indicates what kind of data it contains\n',
#  'Contents (the actual data stored inside)']

# %%
f.readlines()
# Out:
# []

# %%
f=open("Sample.txt")

# %%
data=f.readlines()

# %%
data
# Out:
# ['A file is a collection of data stored on a computer or device under a specific name.\n',
#  '\n',
#  'Examples of files include:\n',
#  '\n',
#  'Documents: report.docx, notes.txt, resume.pdf\n',
#  'Images: photo.jpg, logo.png\n',
#  'Audio: song.mp3\n',
#  'Videos: movie.mp4\n',
#  'Programs: app.exe, script.py\n',
#  '\n',
#  'Each file usually has:\n',
#  '\n',
#  'A name (e.g., vacation_photo)\n',
#  'An extension/type (e.g., .jpg) that indicates what kind of data it contains\n',
#  'Contents (the actual data stored inside)']

# %%
for i in data:
    print(i)
# Out:
# A file is a collection of data stored on a computer or device under a specific name.
#
#
#
# Examples of files include:
#
#
#
# Documents: report.docx, notes.txt, resume.pdf
#
# Images: photo.jpg, logo.png
#
# Audio: song.mp3
#
# Videos: movie.mp4
#
# Programs: app.exe, script.py
#
#
#
# Each file usually has:
#
#
#
# A name (e.g., vacation_photo)
#
# An extension/type (e.g., .jpg) that indicates what kind of data it contains
#
# Contents (the actual data stored inside)

# %%
# convert the data in uppercase

# %%
f=open("Sample.txt")

# %%
data=f.readlines()

# %%
for i in data:
    print(i.upper())
# Out:
# A FILE IS A COLLECTION OF DATA STORED ON A COMPUTER OR DEVICE UNDER A SPECIFIC NAME.
#
#
#
# EXAMPLES OF FILES INCLUDE:
#
#
#
# DOCUMENTS: REPORT.DOCX, NOTES.TXT, RESUME.PDF
#
# IMAGES: PHOTO.JPG, LOGO.PNG
#
# AUDIO: SONG.MP3
#
# VIDEOS: MOVIE.MP4
#
# PROGRAMS: APP.EXE, SCRIPT.PY
#
#
#
# EACH FILE USUALLY HAS:
#
#
#
# A NAME (E.G., VACATION_PHOTO)
#
# AN EXTENSION/TYPE (E.G., .JPG) THAT INDICATES WHAT KIND OF DATA IT CONTAINS
#
# CONTENTS (THE ACTUAL DATA STORED INSIDE)

# %%
#read function

# %%
f=open("Sample.txt")

# %%
f.read()
# Out:
# 'A file is a collection of data stored on a computer or device under a specific name.\n\nExamples of files include:\n\nDocuments: report.docx, notes.txt, resume.pdf\nImages: photo.jpg, logo.png\nAudio: song.mp3\nVideos: movie.mp4\nPrograms: app.exe, script.py\n\nEach file usually has:\n\nA name (e.g., vacation_photo)\nAn extension/type (e.g., .jpg) that indicates what kind of data it contains\nContents (the actual data stored inside)'

# %%
text=f.read()

# %%
text
# Out:
# 'A file is a collection of data stored on a computer or device under a specific name.\n\nExamples of files include:\n\nDocuments: report.docx, notes.txt, resume.pdf\nImages: photo.jpg, logo.png\nAudio: song.mp3\nVideos: movie.mp4\nPrograms: app.exe, script.py\n\nEach file usually has:\n\nA name (e.g., vacation_photo)\nAn extension/type (e.g., .jpg) that indicates what kind of data it contains\nContents (the actual data stored inside)'

# %%
text.split()
# Out:
# ['A',
#  'file',
#  'is',
#  'a',
#  'collection',
#  'of',
#  'data',
#  'stored',
#  'on',
#  'a',
#  'computer',
#  'or',
#  'device',
#  'under',
#  'a',
#  'specific',
#  'name.',
#  'Examples',
#  'of',
#  'files',
#  'include:',
#  'Documents:',
#  'report.docx,',
#  'notes.txt,',
#  'resume.pdf',
#  'Images:',
#  'photo.jpg,',
#  'logo.png',
#  'Audio:',
#  'song.mp3',
#  'Videos:',
#  'movie.mp4',
#  'Programs:',
#  'app.exe,',
#  'script.py',
#  'Each',
#  'file',
#  'usually',
#  'has:',
#  'A',
#  'name',
#  '(e.g.,',
#  'vacation_photo)',
#  'An',
#  'extension/type',
#  '(e.g.,',
#  '.jpg)',
#  'that',
#  'indicates',
#  'what',
#  'kind',
#  'of',
#  'data',
#  'it',
#  'contains',
#  'Contents',
#  '(the',
#  'actual',
#  'data',
#  'stored',
#  'inside)']

# %%
m=open("Marathi.txt",encoding='utf-8')

# %%
m.read()
# Out:
# 'लहान वाक्ये:\n\nभारत हा विविधतेने नटलेला देश आहे.\nझाडे आपल्याला शुद्ध हवा देतात.\nपाणी हे जीवनासाठी अत्यंत आवश्यक आहे.\nस्वच्छता राखणे ही प्रत्येकाची जबाबदारी आहे.\nशिक्षणामुळे व्यक्तीचा सर्वांगीण विकास होतो'

# %%
m.close()

# %%
m.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 m.readable()
#
# ValueError: I/O operation on closed file

# %%
# opening a file with context manager

# %%
with open("Sample.txt") as f:
    data=f.read()

# %%
data
# Out:
# 'A file is a collection of data stored on a computer or device under a specific name.\n\nExamples of files include:\n\nDocuments: report.docx, notes.txt, resume.pdf\nImages: photo.jpg, logo.png\nAudio: song.mp3\nVideos: movie.mp4\nPrograms: app.exe, script.py\n\nEach file usually has:\n\nA name (e.g., vacation_photo)\nAn extension/type (e.g., .jpg) that indicates what kind of data it contains\nContents (the actual data stored inside)\n'

# %%
# writing in file

# %%
f=open("myfile.txt","w")

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines=["frode took the ring","he started his journey to mount data."]

# %%
f.writelines(lines)

# %%
sent="frode took the ring","he started his journey to mount data."

# %%
#write into a myfile.txt with content manager
#use write function  and add 3 separate lines

# %%
with open("myfile.txt", 'w') as f:
    f.write("this is first line\n")
    f.write("this is second line\n")
    f.write("this is third line\n")

# %%
# simple file copy operation

# %%
s=open("sample.txt","r")
f=open("myfile.txt","w")

# %%
contents=s.read()
f.write(contents)
# Out:
# 423

# %%
# append

# %%
s=open("Sample.txt","a")
s.write("\ndone")
# Out:
# 5
